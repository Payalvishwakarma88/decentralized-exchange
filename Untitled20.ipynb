# %% [markdown]
# <a href="https://colab.research.google.com/github/Payalvishwakarma88/decentralized-exchange/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/Student Depression Dataset.csv")


df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                  5
# 1           8  Female   24      Bangalore    Student                  2
# 2          26    Male   31       Srinagar    Student                  3
# 3          30  Female   28       Varanasi    Student                  3
# 4          32  Female   25         Jaipur    Student                  4
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                  5
# 27897  140686    Male   27       Ludhiana    Student                  2
# 27898  140689    Male   31      Faridabad    Student                  3
# 27899  140690  Female   18       Ludhiana    Student                  5
# 27900  140699    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  int64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  int64
#  6   Work Pressure                          27901 non-null  int64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  int64
#  9   Job Satisfaction                       27901 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df["Financial Stress"] = df["Financial Stress"].fillna(df["Financial Stress"].mean())

# %%
df.columns
df["Gender"] = df["Gender"].astype("category")
df["Gender"] = df["Gender"].cat.codes
df["Gender"] = df["Gender"].astype(int)
df["Family History of Mental Illness"] = df["Family History of Mental Illness"].replace({"No":0,"Yes":1})
df["Have you ever had suicidal thoughts ?"] = df["Have you ever had suicidal thoughts ?"].replace({"No":0,"Yes":1})
df["Dietary Habits"] = df["Dietary Habits"].replace({"No":0,"Yes":1})
# Out:
# /tmp/ipython-input-1490234685.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Family History of Mental Illness"] = df["Family History of Mental Illness"].replace({"No":0,"Yes":1})
# /tmp/ipython-input-1490234685.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Have you ever had suicidal thoughts ?"] = df["Have you ever had suicidal thoughts ?"].replace({"No":0,"Yes":1})

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in df.columns:
  sns.histplot(df[i])
  plt.show()

# sns.histplot(df["id"])
# plt.show()

# sns.histplot(df["Age"])
# plt.show()


# sns.histplot(df["Gender"])
# plt.show()

# sns.histplot(df["City"])
# plt.show()


# sns.histplot(df["Profession"])
# plt.show()

# sns.histplot(df["Academic Pressure"])
# plt.show()


# sns.histplot(df["Work Pressure"])
# plt.show()

# sns.histplot(df["CGPA"])
# plt.show()

# sns.histplot(df[""])
# plt.show()


# sns.histplot(df["Family History of Mental Illness"])
# plt.show()


# sns.histplot(df["Have you ever had suicidal thoughts ?"])
# plt.show()


# sns.histplot(df["Dietary Habits"])
# plt.show()


# sns.histplot(df["Financial Stress"])
# plt.show()

# %%
sns.scatterplot(x=df["Depression"],y=df["CGPA"],data=df)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

#data set
df = pd.read_csv("/content/Student Depression Dataset.csv")
df
x = df[["Age"]]
y = df["Depression"]



#spliting the data
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2)

#algorithm
model = LinearRegression()

#training the model
model.fit(x_train, y_train)

#testing the model
model.fit(x_train, y_train)

#testing
y_pred = model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print(MAE)

#testing
y_pred = model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print("mean absolute error:", MAE)
accu = r2_score(y_test, y_pred)
print("accuracy score:", accu*100)
# Out:
# 0.462223626336324
# mean absolute error: 0.462223626336324
# accuracy score: 4.604428093490354

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

#data set
df = pd.read_csv("/content/Student Depression Dataset.csv")
df
x = df[["id","Age","Academic Pressure"]]
y = df["Depression"]



#spliting the data
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2)

#algorithm
model = LinearRegression()

#training the model
model.fit(x_train, y_train)

#testing the model
model.fit(x_train, y_train)

#testing
y_pred = model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print(MAE)

#testing
y_pred = model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print("mean absolute error:", MAE)
accu = r2_score(y_test, y_pred)
print("accuracy score:", accu*100)
# Out:
# 0.35821652139057664
# mean absolute error: 0.35821652139057664
# accuracy score: 25.553688632850992

# %%
""
